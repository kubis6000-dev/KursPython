# %% [markdown]
# <a href="https://colab.research.google.com/github/kubis6000-dev/KursPython/blob/main/python_opis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Język Python

# %% [markdown]
# ## Zmienne
#
# Zmienna w Pythonie to nazwana etykieta (referencja) wskazująca na obiekt w pamięci komputera. Działa jak „pudełko”, w którym przechowujesz dane.
#
# **Typy zmiennych**
#
# - str
# - bool
# - int
# - float
#
# **Przykład**
# ```
# wiek = 16
# imie = 'Antek'
# wzrost= 1.70
# logiczna = True
# ```

# %%
wiek = 16
imie = 'Antek'
wzrost= 1.70
logiczna = True

print(f'Mam na imię {imie}, mam {wiek}, lat, mój wzrost to {wzrost} m, Czy lubię chodzićdo kina? {logiczna}')
# Out:
# Mam na imię Antek, mam 16, lat, mój wzrost to 1.7 m, Czy lubię chodzićdo kina? True

# %% [markdown]
# ## Listy
